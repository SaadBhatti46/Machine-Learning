# %%
import numpy as np
import matplotlib.pyplot as plt
# !pip install ipympl
# %matplotlib widget

# %%
xtrain = np.array([1.0,2.0])
ytrain = np.array([300.0, 500.0])
print(xtrain)
print(ytrain)
# Out:
# [1. 2.]
# [300. 500.]

# %%
print(f"xtrain.shape: {xtrain.shape}")
m = xtrain.shape[0]
# m = len(xtrain)
print(f"Number of training example is: {m}")
# Out:
# xtrain.shape: (2,)
# Number of training example is: 2

# %%
plt.scatter(xtrain, ytrain, marker='x', c='r')
plt.title("Housing Prices")
plt.ylabel("Prices in 1000$ of Dollars")
plt.xlabel("Size in feet")
plt.show()

# %%
w = 100
b = 100

# %% [markdown]
# ## Model function
#
# <img align="left" src="./images/C1_W1_L3_S1_model.png"     style=" width:380px; padding: 10px; " > As described in lecture, the model function for linear regression (which is a function that maps from `x` to `y`) is represented as
#
# $$ f_{w,b}(x^{(i)}) = wx^{(i)} + b \tag{1}$$
#
# The formula above is how you can represent straight lines - different values of $w$ and $b$ give you different straight lines on the plot. <br/> <br/> <br/> <br/> <br/>
#
# Let's try to get a better intuition for this through the code blocks below. Let's start with $w = 100$ and $b = 100$.
#
# **Note: You can come back to this cell to adjust the model's w and b parameters**

# %%
def linear_regression_model(x, w, b):
  print(x)
  m = x.shape[0]
  f_wb = np.zeros(m)
  print(f_wb)
  for i in range(m):
    f_wb[i] = w * x[i] + b
    # for  x(0) , f_wb = w * x[0] + b
    # for  x(1) , f_wb = w * x[1] + b

  return f_wb

# %%
tmp_f_wb = linear_regression_model(xtrain, w, b)

# Plot our model prediction
plt.plot(xtrain, tmp_f_wb, c='b', label='Our Prediction')

# Plot the data points
plt.scatter(xtrain, ytrain, marker='x', c='r', label='Actual Values')

plt.title("Housing Price")
plt.ylabel("Prices in 1000 Dollars")
plt.xlabel("Size in 1000 Sqft")
plt.legend()
plt.show()
# Out:
# [1. 2.]
# [0. 0.]

# %%
w = 200
b = 100
# x_i = 1.2
# cost_1200sqft = w * x_i + b

# print(f"${cost_1200sqft:.0f} thousand dollars")

# %%
tmp_f_wb = linear_regression_model(xtrain, w, b)

# Plot our model prediction
plt.plot(xtrain, tmp_f_wb, c='b', label='Our Prediction')

# Plot the data points
plt.scatter(xtrain, ytrain, marker='x', c='r', label='Actual Values')

plt.title("Housing Price")
plt.ylabel("Prices in 1000 Dollars")
plt.xlabel("Size in 1000 Sqft")
plt.legend()
plt.show()
# Out:
# [1. 2.]

# %% [markdown]
# # **Testing DataSet**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('/content/sample_data/california_housing_test.csv')
dataset.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0

# %%
# print(dataset['total_bedrooms'])
xtrain = dataset['households']
xtrain = np.array(xtrain)
print(xtrain.shape[0])
# print(xtrain.shape[0])
# print(xtrain)
# xtrain

ytrain = dataset['median_income']
# print(ytrain)
ytrain = np.array(ytrain)
print(ytrain.shape[0])
# Out:
# 3000
# 3000

# %%
w = 200
b = 0

def housing_regression(x, w, b):
  m = x.shape[0]
  print(m)
  f_wb = np.zeros(m)
  print(f_wb)
  for i in range(m):
    f_wb[i] = w * x[i] + b
  return f_wb

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
tmp_fwb = housing_regression(xtrain, w, b)

plt.plot(xtrain, tmp_fwb, c='b', label='Our Prediction')
plt.scatter(xtrain, ytrain, marker='x', c='r', label='Actual Values')

plt.title('Housing Prices')
plt.xlabel('Bedrooms')
plt.ylabel('Prices')
plt.legend()
plt.show()
# Out:
# 3000
# [0. 0. 0. ... 0. 0. 0.]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from google.colab import output
output.disable_custom_widget_manager()

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:
